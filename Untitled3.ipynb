# %% [markdown]
# <a href="https://colab.research.google.com/github/Brisa-02/Ejemplo_Colab1/blob/VERISION_02/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
print("Hola SENATI")
# Out:
# Hola SENATI
